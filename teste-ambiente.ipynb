# %% [markdown]
# # Python para Ciência de Dados: O Primeiro Passo para Configurar Seu Ambiente 💻
#
# Quer começar na Ciência de Dados, mas não sabe nem por onde instalar o Python? Relaxa, que esse guia vai te ajudar a configurar tudo. Vamos transformar aquela tela preta do terminal em sua melhor amiga. 😉
#
# ## 🌟 Por que Python para Ciência de Dados?
# Python é tipo aquele amigo gente boa: simples, flexível e resolve tudo. Com bibliotecas como Pandas, NumPy e Matplotlib, você pode fazer desde análises básicas até modelos de aprendizado de máquina surpreendentes. Sim, é a escolha dos sonhos. 🎨
#
# ## Passo 1: Baixando o Python (Sem Drama!)
# 1. **Acesse o site oficial**:
#    Entre em [python.org](https://www.python.org) e baixe a última versão estável.
#    Se está na dúvida qual a versão estável, escolha o seu sistema operacional:
#
#    > É claro que você pode testar as novas versões, mas se precisar de algo seguro, é sempre bom pegar a mais estável.
#
# 2. **Instale com calma**:
#    - No **Windows**, lembre de marcar “Add Python to PATH”. É tipo o truque para evitar dores de cabeça mais tarde.
#    - No **macOS/Linux**, siga as instruções do instalador.
#
# 3. **Teste a instalação**:
#    Abra o terminal (ou prompt de comando) e digite:
#    ```bash
#       python --version
#    ```
#
# Se aparecer a versão do Python, parabéns! Você está no caminho certo. 🎉
#
# ## Passo 2: E o Pip? Já Tá Instalado?
# O pip é o gerenciador de pacotes do Python. Normalmente, ele já vem instalado. Para checar:
#
#    ```bash
#       pip --version
#    ```
#
# ## Passo 3: Criando Ambientes Virtuais (Sim, Isso é Importante!)
# Um ambiente virtual é tipo um “universo paralelo” para cada projeto. Assim, você evita bagunça nas bibliotecas instaladas e os famosos problemas de dependência e versões.
#
# 1. **Crie o ambiente**:
#
#    ```bash
#    	python -m venv venv
#    ```
#
#    > Você pode colocar o nome do ambiente no lugar do segundo `venv`. Por convenção, sempre crio como `venv`.
#
# 2. **Ative o ambiente**:
#
#    . No Windows:
#       ```bash
#          venv\Scripts\activate
#       ```
#
#    . No macOS/Linux:
#       ```bash
#          source venv/bin/activate
#       ```
#    Se aparecer o (venv), sinal de que seu ambiente virtual foi ativado com sucesso.
#
# 3. **Desative quando não precisar mais**:
#
#    ```bash
#       deactivate
#    ```
#
# Viu? Não tem mistério. 🎩
#
# ## Passo 4: Instalando as Ferramentas de Trabalho
# Agora é a hora de baixar as bibliotecas essenciais. Com o ambiente virtual ativo, rode este comando:
#
#    ```bash
#       pip install numpy pandas matplotlib seaborn scikit-learn
#    ```
#
# Pronto! Você tem as “ferramentas básicas” para arrasar na Ciência de Dados. ⚡
#
# Para verificar as bibliotecas instaladas no seu ambiente Python, você pode usar o comando:
#
#    ```bash
#       pip list
#    ```
#
# ## Passo 5: Escolha seu Quartel-General (IDE)
# Uma boa IDE é como a casa dos seus projetos. Aqui estão as mais populares:
#
# ### 1. Jupyter Notebook:
#    . Ideal para análises exploratórias.
#    . Instale com:
#       ```bash
#       pip install notebook
#       ```
#    . Rode com:
#       ```bash
#          jupyter notebook
#       ```
#
# ### 2. VS Code:
#    Sou suspeita em relação ao VS Code, pois ele é meu queridinho devido à sua versatilidade, permitindo-me abrir todos os projetos com os quais costumo trabalhar no dia a dia (sim, me julguem, eu o uso até para desenvolver em Java).
#    . Baixe na Microsoft Store.
#    . Adicione as extensões Python e Jupyter para completar a experiência.
#
# 3. PyCharm:
#    . O PyCharm é um dos IDEs mais populares para desenvolvimento em Python, criado pela JetBrains. Ele é amplamente utilizado por desenvolvedores devido aos seus recursos avançados que facilitam o trabalho com Python, além de suporte para frameworks e bibliotecas amplamente usados, ele possui versões gratuitas para estudantes, professores e comunidade.
#    . Você pode baixar direto no site da JetBrains ele tem versão para Windows, macOS e Linux.
#
# ## Teste Final: Dando Vida ao Ambiente
#
# Crie um script simples para ver se tudo está funcionando:
#
# Crie um arquivo Jupyter Notebook no VS Code:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Não esqueça de ativar seu ambiente!
#
# > Importante! — Pode ser que apareça uma janela para você escolher o ambiente, nesse caso escolha o “Python Enviroments…” e depois a seu ambiente virtual criado anteriormente.
#
# Agora vamos testar criando uma tabela e um gráfico simples:

# %%
# Criando um DataFrame
dados = {'Nome': ['José', 'João', 'Maria'], 'Idade': [23, 35, 29]}
df = pd.DataFrame(dados)
print(df)

# Visualizando um gráfico
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title('Meu Primeiro Gráfico')
plt.show()
# Out:
#     Nome  Idade
# 0   José     23
# 1   João     35
# 2  Maria     29

# %% [markdown]
# Se você conseguir ver a tabela e o gráfico, parabéns! Seu ambiente está pronto para aventuras. 🚀
#
# Configurar o ambiente é o primeiro passo para entrar no universo da Ciência de Dados. Agora que você está pronto(a), é só escolher um projeto e começar. E lembre-se: todo mundo começa de algum lugar. Bora brilhar!
